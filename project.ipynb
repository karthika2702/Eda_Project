# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv(r'C:\DataScience\Projects\canteen_shop_data.csv')
data
# Out:
#            Date   Time      Item  Price  Quantity  Total  Customer ID  \
# 0    01-04-2024  12:15  Sandwich    4.5         2    9.0            1
# 1    01-04-2024  12:30     Drink    1.5         1    1.5            2
# 2    01-04-2024  12:45     Salad    5.0         1    5.0            3
# 3    01-04-2024  13:00    Burger    5.5         1    5.5            4
# 4    01-04-2024  13:15  Sandwich    4.5         1    4.5            5
# ..          ...    ...       ...    ...       ...    ...          ...
# 195  25-04-2024  12:45    Burger    5.5         2   11.0          196
# 196  25-04-2024  13:00  Sandwich    4.5         1    4.5          197
# 197  25-04-2024  13:15     Drink    1.5         1    1.5          198
# 198  25-04-2024  13:30     Salad    5.0         2   10.0          199
# 199  25-04-2024  13:45    Burger    5.5         1    5.5          200
#
#      Payment Method  Employee ID  Customer Satisfaction Weather Special Offers
# ...

# %%
print(data.to_string())
# Out:
#            Date   Time      Item  Price  Quantity  Total  Customer ID  Payment Method  Employee ID  Customer Satisfaction Weather Special Offers
# 0    01-04-2024  12:15  Sandwich    4.5         2    9.0            1            Cash          101                      4   Sunny            Yes
# 1    01-04-2024  12:30     Drink    1.5         1    1.5            2            Card          102                      3   Sunny             No
# 2    01-04-2024  12:45     Salad    5.0         1    5.0            3  Mobile Payment          103                      5  Cloudy            Yes
# 3    01-04-2024  13:00    Burger    5.5         1    5.5            4            Cash          104                      4   Sunny             No
# 4    01-04-2024  13:15  Sandwich    4.5         1    4.5            5            Card          105                      3   Sunny            Yes
# ...

# %%
data.isnull().sum()
# Out:
# Date                     0
# Time                     0
# Item                     0
# Price                    0
# Quantity                 0
# Total                    0
# Customer ID              0
# Payment Method           0
# Employee ID              0
# Customer Satisfaction    0
# Weather                  0
# Special Offers           0
# dtype: int64

# %%
for i in data:
    print(i)
    j=i.replace(' ','_')
    print(j)
    data=data.rename(columns={i:j})
# Out:
# Date
# Date
# Time
# Time
# Item
# Item
# Price
# Price
# Quantity
# Quantity
# Total
# Total
# Customer ID
# Customer_ID
# Payment Method
# Payment_Method
# Employee ID
# Employee_ID
# Customer Satisfaction
# Customer_Satisfaction
# Weather
# Weather
# Special Offers
# Special_Offers

# %%
data
# Out:
#            Date   Time      Item  Price  Quantity  Total  Customer_ID  \
# 0    01-04-2024  12:15  Sandwich    4.5         2    9.0            1
# 1    01-04-2024  12:30     Drink    1.5         1    1.5            2
# 2    01-04-2024  12:45     Salad    5.0         1    5.0            3
# 3    01-04-2024  13:00    Burger    5.5         1    5.5            4
# 4    01-04-2024  13:15  Sandwich    4.5         1    4.5            5
# ..          ...    ...       ...    ...       ...    ...          ...
# 195  25-04-2024  12:45    Burger    5.5         2   11.0          196
# 196  25-04-2024  13:00  Sandwich    4.5         1    4.5          197
# 197  25-04-2024  13:15     Drink    1.5         1    1.5          198
# 198  25-04-2024  13:30     Salad    5.0         2   10.0          199
# 199  25-04-2024  13:45    Burger    5.5         1    5.5          200
#
#      Payment_Method  Employee_ID  Customer_Satisfaction Weather Special_Offers
# ...

# %%
data= data.rename(columns=str.capitalize)

# %%
data
# Out:
#            Date   Time      Item  Price  Quantity  Total  Customer_id  \
# 0    01-04-2024  12:15  Sandwich    4.5         2    9.0            1
# 1    01-04-2024  12:30     Drink    1.5         1    1.5            2
# 2    01-04-2024  12:45     Salad    5.0         1    5.0            3
# 3    01-04-2024  13:00    Burger    5.5         1    5.5            4
# 4    01-04-2024  13:15  Sandwich    4.5         1    4.5            5
# ..          ...    ...       ...    ...       ...    ...          ...
# 195  25-04-2024  12:45    Burger    5.5         2   11.0          196
# 196  25-04-2024  13:00  Sandwich    4.5         1    4.5          197
# 197  25-04-2024  13:15     Drink    1.5         1    1.5          198
# 198  25-04-2024  13:30     Salad    5.0         2   10.0          199
# 199  25-04-2024  13:45    Burger    5.5         1    5.5          200
#
#      Payment_method  Employee_id  Customer_satisfaction Weather Special_offers
# ...

# %%
data.describe()
# Out:
#             Price    Quantity       Total  Customer_id  Employee_id  \
# count  200.000000  200.000000  200.000000   200.000000   200.000000
# mean     4.125000    1.365000    5.910000   100.500000   200.500000
# std      1.560143    0.482638    3.359813    57.879185    57.879185
# min      1.500000    1.000000    1.500000     1.000000   101.000000
# 25%      3.750000    1.000000    4.125000    50.750000   150.750000
# 50%      4.750000    1.000000    5.000000   100.500000   200.500000
# 75%      5.125000    2.000000    9.000000   150.250000   250.250000
# max      5.500000    2.000000   11.000000   200.000000   300.000000
#
#        Customer_satisfaction
# count             200.000000
# mean                3.895000
# std                 0.785532
# min                 3.000000
# 25%                 3.000000
# 50%                 4.000000
# 75%                 5.000000
# max                 5.000000

# %%
data.head()
# Out:
#          Date   Time      Item  Price  Quantity  Total  Customer_id  \
# 0  01-04-2024  12:15  Sandwich    4.5         2    9.0            1
# 1  01-04-2024  12:30     Drink    1.5         1    1.5            2
# 2  01-04-2024  12:45     Salad    5.0         1    5.0            3
# 3  01-04-2024  13:00    Burger    5.5         1    5.5            4
# 4  01-04-2024  13:15  Sandwich    4.5         1    4.5            5
#
#    Payment_method  Employee_id  Customer_satisfaction Weather Special_offers
# 0            Cash          101                      4   Sunny            Yes
# 1            Card          102                      3   Sunny             No
# 2  Mobile Payment          103                      5  Cloudy            Yes
# 3            Cash          104                      4   Sunny             No
# 4            Card          105                      3   Sunny            Yes

# %% [markdown]
# ##

# %% [markdown]
# ##

# %% [markdown]
# #### **    Identifying the mode of payment most preferred

# %%
pivot = pd.pivot_table(
    data=data,
    index='Payment_method',
    values='Customer_satisfaction'
)
print(pivot)
# this data indicates that customers prefer cash payyment over other types of payment methods
# Out:
#                 Customer_satisfaction
# Payment_method
# Card                         3.911765
# Cash                         4.180328
# Mobile Payment               3.633803

# %%
pivot = pd.pivot_table(
    data=data,
    index='Payment_method',
    values='Customer_satisfaction'
).reset_index()

plt.figure(figsize=(8, 4))  
sns.barplot(data=pivot, x='Customer_satisfaction', y='Payment_method', palette='Set2')
plt.xlabel('Customer Satisfaction')
plt.ylabel('Payment Method')
plt.title('Average Customer Satisfaction by Payment Method')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6580\2989771095.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=pivot, x='Customer_satisfaction', y='Payment_method', palette='Set2')

# %% [markdown]
# ### The above chart clearly indicates that the Customers prefer cash payment over other modes of payment

# %% [markdown]
# ##

# %% [markdown]
# ### **   Identifying the food item sold more

# %%
pivot = pd.pivot_table(
    data=data,
    index='Item',
    values='Total'
)

print(pivot)
#Burgers are sold more
# Out:
#           Total
# Item
# Burger     8.03
# Drink      1.56
# Salad      7.30
# Sandwich   6.75

# %%
pivot = pd.pivot_table(
    data=data,
    index='Item',
    values='Total'
).reset_index()

plt.figure(figsize=(5, 6))  


sns.barplot(data=pivot, x='Item', y='Total',color='grey')
plt.xlabel('Item')
plt.ylabel('Total')
plt.title('Total by Item')

plt.xticks(rotation=45)  
plt.tight_layout()  

plt.show()

# %% [markdown]
# ### Burgers are sold more when compared to other items and drinks are sold the least.

# %% [markdown]
# ##

# %% [markdown]
# ### ** categorising items based on their selling price

# %%
pivot = pd.pivot_table(
    data=data,
    index='Item',
    values='Price'
)
print(pivot)
# Out:
#           Price
# Item
# Burger      5.5
# Drink       1.5
# Salad       5.0
# Sandwich    4.5

# %%
pivot = pd.pivot_table(
    data=data,
    index='Item',
    values='Price'
)


plt.figure(figsize=(4, 6))
sns.barplot(x=pivot.index, y="Price", data=pivot, palette="Set2")
plt.xlabel("Item")
plt.ylabel("Price")
plt.title("Price Distribution by Item")
plt.xticks(rotation=45) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6580\3769457534.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pivot.index, y="Price", data=pivot, palette="Set2")

# %% [markdown]
# ### Burgers are the most expensive item in the shop

# %% [markdown]
# ##

# %% [markdown]
# ### **  Do weather conditions play a role in the customer eating pattern

# %%
weather_data = data.groupby('Weather')['Total'].sum().reset_index()


plt.figure(figsize=(8, 8))
plt.pie(weather_data['Total'], labels=weather_data['Weather'], autopct='%1.1f%%', colors=plt.cm.tab20.colors)
plt.title('total sales by Weather')
plt.show()

# %% [markdown]
# ### weather conditions do affect the eating habit of people. During sunny days customers prefer to eat more. The chart indicates that about 50% of a shop's transactions takesplace during sunny days

# %% [markdown]
# #

# %% [markdown]
# ##

# %% [markdown]
# ###  **Do special offers affect the sales attitude

# %%
offer_data = data.groupby('Special_offers')['Total'].sum().reset_index()


plt.figure(figsize=(8, 8))
plt.pie(offer_data['Total'], labels=offer_data['Special_offers'], autopct='%1.1f%%', colors=plt.cm.tab20.colors)
plt.title('Total sales by Offers')
plt.show()

# %% [markdown]
# ### It is clear that the special offers provided by the shop dont have any significance over the selling behavior.People tend to buy more even during the non offer times.

# %% [markdown]
# ##

# %% [markdown]
# ##

# %% [markdown]
# ### **  Identify the busiest transaction time in the canteen

# %%
pivot = pd.pivot_table(
    data=data,
    index='Time',
    values='Total'
).reset_index()

plt.figure(figsize=(7, 6)) 
sns.barplot(data=pivot, x='Time', y='Total', palette='husl')  
plt.xlabel('Time')
plt.ylabel('Total')
plt.title('Total sales by Time')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6580\752816140.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=pivot, x='Time', y='Total', palette='husl')

# %% [markdown]
# ### The study shows that the peak time, where most of the transactions takesplace in the said shop is at 2'O' clock

# %% [markdown]
# ###

# %% [markdown]
# ##

# %% [markdown]
# ## The provided dataset reflects the various conditions that affect the selling activities in a canteen. It also shows the customer preference on the basis of payment mode , weather pattern and special offers
